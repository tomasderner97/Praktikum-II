# %% [markdown]
# # Název

# %%
import zpracovani as z
from IPython.display import display
# %matplotlib inline

# %%
u4p, u4s = init_u4()
display(u4p)
display(u4s)
# Out:
# C:\Users\tomas\Google Drive\Documents\MatFyz\Praktikum\Elektřina a magnetizmus\Protokoly\6\calc\zpracovani.py:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   p = pd.read_csv("../raw/u4p.txt", sep=r"\s*,\s*")
# C:\Users\tomas\Google Drive\Documents\MatFyz\Praktikum\Elektřina a magnetizmus\Protokoly\6\calc\zpracovani.py:11: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   s = pd.read_csv("../raw/u4s.txt", sep=r"\s*,\s*")
#     C     U      I      P
# 0   1  50.1  0.053  2.533
# 1   2  50.1  0.060  2.555
# 2   3  50.1  0.070  2.500
# 3   4  50.4  0.083  2.577
# 4   5  50.5  0.096  2.583
# ...

# %%
dir(z)
# Out:
# ['FitCurve',
#  'Spline',
#  'USpline',
#  'UnivariateSpline',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__warningregistry__',
#  'arr',
#  'curve_fit',
#  'eval_mean',
#  'f_cubic',
#  'f_exp',
#  'f_exp_simple',
#  'f_line',
#  'f_para',
#  'init_u1',
#  'init_u4',
#  'init_u5',
#  'latex_table',
#  'main',
#  'mpl',
#  'noms',
#  'pd',
#  'plt',
#  'relative',
#  'round_uncert',
#  'sp',
#  'split_df_uncert',
#  'stds',
#  'uf',
#  'um',
#  'uncertainties',
#  'unumpy']

# %%
plt.plot(u4p.C, u4p.P)
plt.plot(u4s.C, u4s.P)

# %%
u5 = init_u5()
u5
# Out:
# C:\Users\tomas\Google Drive\Documents\MatFyz\Praktikum\Elektřina a magnetizmus\Protokoly\6\calc\zpracovani.py:16: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv("../raw/u5.txt", sep=r"\s*,\s*")
#        C     U      I      P
# 0    1.0  49.7  0.021  0.668
# 1    1.1  49.7  0.023  0.826
# 2    1.2  49.4  0.024  0.978
# 3    1.3  49.3  0.026  1.107
# 4    1.4  49.1  0.027  1.211
# 5    1.5  49.0  0.028  1.291
# 6    1.6  49.0  0.029  1.351
# 7    1.7  48.9  0.029  1.391
# 8    1.8  48.8  0.029  1.408
# 9    1.9  48.7  0.029  1.421
# 10   2.0  48.7  0.029  1.436
# 11   2.1  48.8  0.029  1.423
# 12   2.2  48.8  0.029  1.427
# 13   2.3  48.7  0.029  1.417
# 14   2.4  48.7  0.029  1.405
# 15   2.5  48.8  0.029  1.391
# 16   2.6  48.9  0.029  1.382
# 17   2.7  48.7  0.029  1.368
# ...

# %%
spl = Spline(u5.C, u5.P)
spl.set_smoothing_factor(0.002)
plt.plot(*spl.curve())
plt.plot(u5.C, u5.P, "x")
plt.savefig("../plot/u5.pdf")
